# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math
import pylab as pl

# %%
mood_data = pd.read_excel('2021_Mood_Calendar.xlsx')

# %%
mood_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date                     365 non-null    datetime64[ns]
#  1   Mood (Morning)           40 non-null     object
#  2   Mood (Afteroon/Evening)  40 non-null     object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 8.7+ KB

# %%
#remove rows that don't have mood data
mood_data_indexes = mood_data['Mood (Morning)'].notnull()
mood_data = mood_data[mood_data_indexes]

# %%
x_labels = mood_data['Mood (Morning)'].unique()
y_vals_morning = mood_data['Mood (Morning)'].value_counts()
y_vals_pos_morn = [y_vals_morning[x_labels[0]], y_vals_morning[x_labels[1]], y_vals_morning[x_labels[2]]]

plt.bar(x_labels, height=y_vals_pos_morn, color=x_labels)
plt.xlabel("Mood")
plt.ylabel("Count")
plt.title("Total Days per Mood (Mornings)")
# Out:
# Text(0.5, 1.0, 'Total Days per Mood (Mornings)')

# %%
y_vals_evening = mood_data['Mood (Afteroon/Evening)'].value_counts()
y_vals_pos_evening = [y_vals_evening[x_labels[0]], y_vals_evening[x_labels[1]], y_vals_evening[x_labels[2]]]

plt.bar(x_labels, height=y_vals_pos_evening, color=x_labels)
plt.xlabel("Mood")
plt.ylabel("Count")
plt.title("Total Days per Mood (Afteroon/Evening)")
# Out:
# Text(0.5, 1.0, 'Total Days per Mood (Afteroon/Evening)')

# %%
y_vals_total = y_vals_morning + y_vals_evening

y_vals_pos_total = [y_vals_total[x_labels[0]], y_vals_total[x_labels[1]], y_vals_total[x_labels[2]]]

plt.bar(x_labels, height=y_vals_pos_total, color=x_labels)
plt.xlabel("Mood")
plt.ylabel("Count")
plt.title("Total Days per Mood")
# Out:
# Text(0.5, 1.0, 'Total Days per Mood')

# %%
fig1, ax1 = plt.subplots()
plt.title("Mood Frequencies")
ax1.pie(y_vals_pos_total, labels=x_labels, colors=x_labels,
        startangle=90, autopct='%1.1f%%', textprops={'color':"w"})
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
#https://i.redd.it/34yw8wbhv3961.png
